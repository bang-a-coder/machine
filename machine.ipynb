# %%
import seaborn as sns

iris = sns.load_dataset('iris')

iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# %matplotlib inline
sns.pairplot(iris, hue='species', size=2);
# Out:
# /Users/nikitasfilosofof/.pyenv/versions/3.9.1/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## Break down data into the features matrix (X_iris) that contains our independent variables
X_iris = iris.drop('species',axis=1)

## Extract Target array/vector that is our dependent variable
y_iris = iris['species']
print(X_iris.shape,y_iris.shape)
# Out:
# (150, 4) (150,)
